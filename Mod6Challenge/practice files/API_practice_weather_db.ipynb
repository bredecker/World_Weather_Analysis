# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a practice set of random latitude and longitude combinations
lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(25.12903645, -67.59741259), (25.92017388, 11.09532135), (26.62509167, 74.84233102), (-59.98969384, -76.89176677), (37.30571269, -61.13376282)]

# %%
for coordinate in coordinates: 
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name, 
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# cockburn town tc
# gat ly
# parvatsar in
# punta arenas cl
# saint george bm

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 5

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&appid=a37a5508179f05bd6b3be8813c556848"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/forecast?id=524901&appid=a37a5508179f05bd6b3be8813c556848

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"cod":"200","message":0,"cnt":40,"list":[{"dt":1680577200,"main":{"temp":281.9,"feels_like":279.4,"temp_min":280.86,"temp_max":281.9,"pressure":1015,"sea_level":1015,"grnd_level":1017,"humidity":65,"temp_kf":1.04},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"clouds":{"all":100},"wind":{"speed":4.47,"deg":227,"gust":14.11},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2023-04-04 03:00:00"},{"dt":1680588000,"main":{"temp":281.6,"feels_like":279.64,"temp_min":280.99,"temp_max":281.6,"pressure":1016,"sea_level":1016,"grnd_level":1017,"humidity":69,"temp_kf":0.61},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"clouds":{"all":99},"wind":{"speed":3.26,"deg":224,"gust":8.51},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2023-04-04 06:00:00"},{"dt":1680598800,"main":{"temp":280.97,"feels_like":280.97,"temp_min":280.5,"temp_max":280.97,"pressure":1016,"sea_level":1016,"grnd_level":1017,"humidity":77,"temp_kf":0.47},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"clouds":{"all":99},"wind":{"speed":1.33,"deg":226,"gust":2.13},"visibility":10000,"pop":0.03,"sys":{"pod":"n"},"dt_txt":"2023-04-04 09:00:00"},{"dt":1680609600,"main":{"temp":281.35,"feels_like":280.82,"temp_min":281.35,"temp_max":281.35,"pressure":1019,"sea_level":1019,"grnd_level":1018,"humidity":81,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"clouds":{"all":99},"wind":{"speed":1.44,"deg":297,"gust":3.2},"visibility":10000,"pop":0.49,"rain":{"3h":0.33},"sys":{"pod":"d"},"dt_txt":"2023-04-04 12:00:00"},{"dt":1680620400,"main":{"temp":283.72,"feels_like":282.56,"temp_min":283.72,"temp_max":283.72,"pressure":1019,"sea_level":1019,"grnd_level":1019,"humidity":66,"temp_kf":0},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"clouds":{"all":100},"wind":{"speed":1.01,"deg":21,"gust":0.71},"visibility":10000,"pop":0.29,"sys":{"pod":"d"},"dt_txt":"2023-04-04 15:00:00"},{"dt":1680631200,"main":{"temp":287.36,"feels_like":286.32,"temp_min":287.36,"temp_max":287.36,"pressure":1019,"sea_level":1019,"grnd_level":1018,"humidity":57,"temp_kf":0},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"clouds":{"all":94},"wind":{"speed":2.15,"deg":69,"gust":2.62},"visibility":10000,"pop":0.29,"sys":{"pod":"d"},"dt_txt":"2023-04-04 18:00:00"},{"dt":1680642000,"main":{"temp":283.58,"feels_like":282.53,"temp_min":283.58,"temp_max":283.58,"pressure":1020,"sea_level":1020,"grnd_level":1020,"humidity":71,"temp_kf":0},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"clouds":{"all":99},"wind":{"speed":3.56,"deg":76,"gust":5.46},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2023-04-04 21:00:00"},{"dt":1680652800,"main":{"temp":281.56,"feels_like":279.57,"temp_min":281.56,"temp_max":281.56,"pressure":1023,"sea_level":1023,"grnd_level":1023,"humidity":82,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"clouds":{"all":100},"wind":{"speed":3.31,"deg":61,"gust":6.05},"visibility":10000,"pop":0.22,"rain":{"3h":0.2},"sys":{"pod":"n"},"dt_txt":"2023-04-05 00:00:00"},{"dt":1680663600,"main":{"temp":280.72,"feels_like":278.94,"temp_min":280.72,"temp_max":280.72,"pressure":1025,"sea_level":1025,"grnd_level":1025,"humidity":83,"temp_kf":0},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"clouds":{"all":100},"wind":{"speed":2.71,"deg":50,"gust":4.82},"visibility":10000,"pop":0.25,"sys":{"pod":"n"},"dt_txt":"2023-04-05 03:00:00"},{"dt":1680674400,"main":{"temp":280.17,"feels_like":277.81,"temp_min":280.17,"temp_max":280.17,"pressure":1026,"sea_level":1026,"grnd_level":1026,"humidity":88,"temp_kf":0},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"clouds":{"all":100},"wind":{"speed":3.43,"deg":48,"gust":6.96},"visibility ...

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1680577200,
#    'main': {'temp': 281.9,
#     'feels_like': 279.4,
#     'temp_min': 280.86,
#     'temp_max': 281.9,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1017,
#     'humidity': 65,
#     'temp_kf': 1.04},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.47, 'deg': 227, 'gust': 14.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-04 03:00:00'},
#   {'dt': 1680588000,
#    'main': {'temp': 281.6,
#     'feels_like': 279.64,
#     'temp_min': 280.99,
#     'temp_max': 281.6,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1017,
#     'humidity': 69,
#     'temp_kf': 0.61},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.26, 'deg': 224, 'gust': 8.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-04 06:00:00'},
#   {'dt': 1680598800,
#    'main': {'temp': 280.97,
#     'feels_like': 280.97,
#     'temp_min': 280.5,
#     'temp_max': 280.97,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1017,
#     'humidity': 77,
#     'temp_kf': 0.47},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.33, 'deg': 226, 'gust': 2.13},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-04 09:00:00'},
#   {'dt': 1680609600,
#    'main': {'temp': 281.35,
#     'feels_like': 280.82,
#     'temp_min': 281.35,
#     'temp_max': 281.35,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.44, 'deg': 297, 'gust': 3.2},
#    'visibility': 10000,
#    'pop': 0.49,
#    'rain': {'3h': 0.33},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 12:00:00'},
#   {'dt': 1680620400,
#    'main': {'temp': 283.72,
#     'feels_like': 282.56,
#     'temp_min': 283.72,
#     'temp_max': 283.72,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1019,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.01, 'deg': 21, 'gust': 0.71},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 15:00:00'},
#   {'dt': 1680631200,
#    'main': {'temp': 287.36,
#     'feels_like': 286.32,
#     'temp_min': 287.36,
#     'temp_max': 287.36,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 2.15, 'deg': 69, 'gust': 2.62},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 18:00:00'},
#   {'dt': 1680642000,
#    'main': {'temp': 283.58,
#     'feels_like': 282.53,
#     'temp_min': 283.58,
#     'temp_max': 283.58,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1020,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.56, 'deg': 76, 'gust': 5.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 21:00:00'},
#   {'dt': 1680652800,
#    'main': {'temp': 281.56,
#     'feels_like': 279.57,
#     'temp_min': 281.56,
#     'temp_max': 281.56,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1023,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.31, 'deg': 61, 'gust': 6.05},
#    'visibility': 10000,
#    'pop': 0.22,
#    'rain': {'3h': 0.2},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 00:00:00'},
#   {'dt': 1680663600,
#    'main': {'temp': 280.72,
#     'feels_like': 278.94,
#     'temp_min': 280.72,
#     'temp_max': 280.72,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.71, 'deg': 50, 'gust': 4.82},
#    'visibility': 10000,
#    'pop': 0.25,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 03:00:00'},
#   {'dt': 1680674400,
#    'main': {'temp': 280.17,
#     'feels_like': 277.81,
#     'temp_min': 280.17,
#     'temp_max': 280.17,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1026,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.43, 'deg': 48, 'gust': 6.96},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 06:00:00'},
#   {'dt': 1680685200,
#    'main': {'temp': 278.47,
#     'feels_like': 274.88,
#     'temp_min': 278.47,
#     'temp_max': 278.47,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1028,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.01, 'deg': 64, 'gust': 9.13},
#    'visibility': 10000,
#    'pop': 0.56,
#    'rain': {'3h': 0.26},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 09:00:00'},
#   {'dt': 1680696000,
#    'main': {'temp': 277.75,
#     'feels_like': 273.68,
#     'temp_min': 277.75,
#     'temp_max': 277.75,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.66, 'deg': 63, 'gust': 10.07},
#    'visibility': 10000,
#    'pop': 0.23,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 12:00:00'},
#   {'dt': 1680706800,
#    'main': {'temp': 278.03,
#     'feels_like': 274.27,
#     'temp_min': 278.03,
#     'temp_max': 278.03,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.14, 'deg': 77, 'gust': 8.44},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 15:00:00'},
#   {'dt': 1680717600,
#    'main': {'temp': 277.68,
#     'feels_like': 273.79,
#     'temp_min': 277.68,
#     'temp_max': 277.68,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1029,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.23, 'deg': 89, 'gust': 8.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 18:00:00'},
#   {'dt': 1680728400,
#    'main': {'temp': 277.71,
#     'feels_like': 274.45,
#     'temp_min': 277.71,
#     'temp_max': 277.71,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1028,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.04, 'deg': 93, 'gust': 7.36},
#    'visibility': 10000,
#    'pop': 0.23,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 21:00:00'},
#   {'dt': 1680739200,
#    'main': {'temp': 277.85,
#     'feels_like': 275.42,
#     'temp_min': 277.85,
#     'temp_max': 277.85,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1027,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.84, 'deg': 67, 'gust': 6.08},
#    'visibility': 10000,
#    'pop': 0.35,
#    'rain': {'3h': 0.66},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 00:00:00'},
#   {'dt': 1680750000,
#    'main': {'temp': 278.31,
#     'feels_like': 276.99,
#     'temp_min': 278.31,
#     'temp_max': 278.31,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.74, 'deg': 52, 'gust': 3.85},
#    'visibility': 10000,
#    'pop': 0.64,
#    'rain': {'3h': 0.52},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 03:00:00'},
#   {'dt': 1680760800,
#    'main': {'temp': 278.7,
#     'feels_like': 278.7,
#     'temp_min': 278.7,
#     'temp_max': 278.7,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1022,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.43, 'deg': 5, 'gust': 0.63},
#    'visibility': 8099,
#    'pop': 0.61,
#    'rain': {'3h': 0.39},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 06:00:00'},
#   {'dt': 1680771600,
#    'main': {'temp': 279.93,
#     'feels_like': 278.97,
#     'temp_min': 279.93,
#     'temp_max': 279.93,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1020,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.63, 'deg': 176, 'gust': 8.64},
#    'visibility': 528,
#    'pop': 0.59,
#    'rain': {'3h': 0.93},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 09:00:00'},
#   {'dt': 1680782400,
#    'main': {'temp': 283.79,
#     'feels_like': 283.49,
#     'temp_min': 283.79,
#     'temp_max': 283.79,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1020,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.63, 'deg': 224, 'gust': 8.1},
#    'visibility': 153,
#    'pop': 0.68,
#    'rain': {'3h': 0.34},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 12:00:00'},
#   {'dt': 1680793200,
#    'main': {'temp': 287.79,
#     'feels_like': 287.79,
#     'temp_min': 287.79,
#     'temp_max': 287.79,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1019,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.98, 'deg': 227, 'gust': 11.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 15:00:00'},
#   {'dt': 1680804000,
#    'main': {'temp': 293.53,
#     'feels_like': 293.56,
#     'temp_min': 293.53,
#     'temp_max': 293.53,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1017,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.34, 'deg': 221, 'gust': 8.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 18:00:00'},
#   {'dt': 1680814800,
#    'main': {'temp': 294.13,
#     'feels_like': 294.14,
#     'temp_min': 294.13,
#     'temp_max': 294.13,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1016,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.25, 'deg': 235, 'gust': 8.93},
#    'visibility': 10000,
#    'pop': 0.18,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 21:00:00'},
#   {'dt': 1680825600,
#    'main': {'temp': 285.6,
#     'feels_like': 285.04,
#     'temp_min': 285.6,
#     'temp_max': 285.6,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1020,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.24, 'deg': 289, 'gust': 13.19},
#    'visibility': 7074,
#    'pop': 1,
#    'rain': {'3h': 3.6},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 00:00:00'},
#   {'dt': 1680836400,
#    'main': {'temp': 283.83,
#     'feels_like': 282.7,
#     'temp_min': 283.83,
#     'temp_max': 283.83,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1021,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.14, 'deg': 294, 'gust': 12.37},
#    'visibility': 10000,
#    'pop': 0.74,
#    'rain': {'3h': 2.66},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 03:00:00'},
#   {'dt': 1680847200,
#    'main': {'temp': 282.21,
#     'feels_like': 279.86,
#     'temp_min': 282.21,
#     'temp_max': 282.21,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1023,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.29, 'deg': 296, 'gust': 11.53},
#    'visibility': 10000,
#    'pop': 0.64,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 06:00:00'},
#   {'dt': 1680858000,
#    'main': {'temp': 280.53,
#     'feels_like': 278.09,
#     'temp_min': 280.53,
#     'temp_max': 280.53,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.7, 'deg': 284, 'gust': 11.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 09:00:00'},
#   {'dt': 1680868800,
#    'main': {'temp': 280.81,
#     'feels_like': 277.8,
#     'temp_min': 280.81,
#     'temp_max': 280.81,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 5.04, 'deg': 282, 'gust': 13.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 12:00:00'},
#   {'dt': 1680879600,
#    'main': {'temp': 283.48,
#     'feels_like': 281.51,
#     'temp_min': 283.48,
#     'temp_max': 283.48,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1025,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 6.86, 'deg': 286, 'gust': 12.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 15:00:00'},
#   {'dt': 1680890400,
#    'main': {'temp': 285.98,
#     'feels_like': 284,
#     'temp_min': 285.98,
#     'temp_max': 285.98,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 7.42, 'deg': 293, 'gust': 12.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 18:00:00'},
#   {'dt': 1680901200,
#    'main': {'temp': 284.8,
#     'feels_like': 282.73,
#     'temp_min': 284.8,
#     'temp_max': 284.8,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 6.36, 'deg': 299, 'gust': 11.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 21:00:00'},
#   {'dt': 1680912000,
#    'main': {'temp': 281.75,
#     'feels_like': 279.5,
#     'temp_min': 281.75,
#     'temp_max': 281.75,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1027,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 3.86, 'deg': 307, 'gust': 8.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 00:00:00'},
#   {'dt': 1680922800,
#    'main': {'temp': 279.32,
#     'feels_like': 276.92,
#     'temp_min': 279.32,
#     'temp_max': 279.32,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1029,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.21, 'deg': 341, 'gust': 6.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 03:00:00'},
#   {'dt': 1680933600,
#    'main': {'temp': 277.43,
#     'feels_like': 274.81,
#     'temp_min': 277.43,
#     'temp_max': 277.43,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1029,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.97, 'deg': 342, 'gust': 5.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 06:00:00'},
#   {'dt': 1680944400,
#    'main': {'temp': 276.37,
#     'feels_like': 274.94,
#     'temp_min': 276.37,
#     'temp_max': 276.37,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.59, 'deg': 332, 'gust': 2.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 09:00:00'},
#   {'dt': 1680955200,
#    'main': {'temp': 277.22,
#     'feels_like': 275.73,
#     'temp_min': 277.22,
#     'temp_max': 277.22,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1031,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.74, 'deg': 310, 'gust': 3.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 12:00:00'},
#   {'dt': 1680966000,
#    'main': {'temp': 280.26,
#     'feels_like': 277.98,
#     'temp_min': 280.26,
#     'temp_max': 280.26,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1031,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 3.33, 'deg': 315, 'gust': 6.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 15:00:00'},
#   {'dt': 1680976800,
#    'main': {'temp': 283.45,
#     'feels_like': 281.24,
#     'temp_min': 283.45,
#     'temp_max': 283.45,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1029,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 79},
#    'wind': {'speed': 3.11, 'deg': 336, 'gust': 6.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 18:00:00'},
#   {'dt': 1680987600,
#    'main': {'temp': 283.44,
#     'feels_like': 281.2,
#     'temp_min': 283.44,
#     'temp_max': 283.44,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1028,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 50},
#    'wind': {'speed': 2.01, 'deg': 359, 'gust': 4.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 21:00:00'},
#   {'dt': 1680998400,
#    'main': {'temp': 279.58,
#     'feels_like': 278.14,
#     'temp_min': 279.58,
#     'temp_max': 279.58,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 2.05, 'deg': 129, 'gust': 3.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-09 00:00:00'}],
#  'city': {'id': 4930956,
#   'name': 'Boston',
#   'coord': {'lat': 42.3584, 'lon': -71.0598},
#   'country': 'US',
#   'population': 617594,
#   'timezone': -14400,
#   'sunrise': 1680517414,
#   'sunset': 1680563473}}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1680577200,
#    'main': {'temp': 281.9,
#     'feels_like': 279.4,
#     'temp_min': 280.86,
#     'temp_max': 281.9,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1017,
#     'humidity': 65,
#     'temp_kf': 1.04},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.47, 'deg': 227, 'gust': 14.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-04 03:00:00'},
#   {'dt': 1680588000,
#    'main': {'temp': 281.6,
#     'feels_like': 279.64,
#     'temp_min': 280.99,
#     'temp_max': 281.6,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1017,
#     'humidity': 69,
#     'temp_kf': 0.61},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.26, 'deg': 224, 'gust': 8.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-04 06:00:00'},
#   {'dt': 1680598800,
#    'main': {'temp': 280.97,
#     'feels_like': 280.97,
#     'temp_min': 280.5,
#     'temp_max': 280.97,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1017,
#     'humidity': 77,
#     'temp_kf': 0.47},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.33, 'deg': 226, 'gust': 2.13},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-04 09:00:00'},
#   {'dt': 1680609600,
#    'main': {'temp': 281.35,
#     'feels_like': 280.82,
#     'temp_min': 281.35,
#     'temp_max': 281.35,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.44, 'deg': 297, 'gust': 3.2},
#    'visibility': 10000,
#    'pop': 0.49,
#    'rain': {'3h': 0.33},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 12:00:00'},
#   {'dt': 1680620400,
#    'main': {'temp': 283.72,
#     'feels_like': 282.56,
#     'temp_min': 283.72,
#     'temp_max': 283.72,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1019,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.01, 'deg': 21, 'gust': 0.71},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 15:00:00'},
#   {'dt': 1680631200,
#    'main': {'temp': 287.36,
#     'feels_like': 286.32,
#     'temp_min': 287.36,
#     'temp_max': 287.36,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 2.15, 'deg': 69, 'gust': 2.62},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 18:00:00'},
#   {'dt': 1680642000,
#    'main': {'temp': 283.58,
#     'feels_like': 282.53,
#     'temp_min': 283.58,
#     'temp_max': 283.58,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1020,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.56, 'deg': 76, 'gust': 5.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 21:00:00'},
#   {'dt': 1680652800,
#    'main': {'temp': 281.56,
#     'feels_like': 279.57,
#     'temp_min': 281.56,
#     'temp_max': 281.56,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1023,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.31, 'deg': 61, 'gust': 6.05},
#    'visibility': 10000,
#    'pop': 0.22,
#    'rain': {'3h': 0.2},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 00:00:00'},
#   {'dt': 1680663600,
#    'main': {'temp': 280.72,
#     'feels_like': 278.94,
#     'temp_min': 280.72,
#     'temp_max': 280.72,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.71, 'deg': 50, 'gust': 4.82},
#    'visibility': 10000,
#    'pop': 0.25,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 03:00:00'},
#   {'dt': 1680674400,
#    'main': {'temp': 280.17,
#     'feels_like': 277.81,
#     'temp_min': 280.17,
#     'temp_max': 280.17,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1026,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.43, 'deg': 48, 'gust': 6.96},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 06:00:00'},
#   {'dt': 1680685200,
#    'main': {'temp': 278.47,
#     'feels_like': 274.88,
#     'temp_min': 278.47,
#     'temp_max': 278.47,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1028,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.01, 'deg': 64, 'gust': 9.13},
#    'visibility': 10000,
#    'pop': 0.56,
#    'rain': {'3h': 0.26},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 09:00:00'},
#   {'dt': 1680696000,
#    'main': {'temp': 277.75,
#     'feels_like': 273.68,
#     'temp_min': 277.75,
#     'temp_max': 277.75,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.66, 'deg': 63, 'gust': 10.07},
#    'visibility': 10000,
#    'pop': 0.23,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 12:00:00'},
#   {'dt': 1680706800,
#    'main': {'temp': 278.03,
#     'feels_like': 274.27,
#     'temp_min': 278.03,
#     'temp_max': 278.03,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.14, 'deg': 77, 'gust': 8.44},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 15:00:00'},
#   {'dt': 1680717600,
#    'main': {'temp': 277.68,
#     'feels_like': 273.79,
#     'temp_min': 277.68,
#     'temp_max': 277.68,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1029,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.23, 'deg': 89, 'gust': 8.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 18:00:00'},
#   {'dt': 1680728400,
#    'main': {'temp': 277.71,
#     'feels_like': 274.45,
#     'temp_min': 277.71,
#     'temp_max': 277.71,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1028,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.04, 'deg': 93, 'gust': 7.36},
#    'visibility': 10000,
#    'pop': 0.23,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 21:00:00'},
#   {'dt': 1680739200,
#    'main': {'temp': 277.85,
#     'feels_like': 275.42,
#     'temp_min': 277.85,
#     'temp_max': 277.85,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1027,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.84, 'deg': 67, 'gust': 6.08},
#    'visibility': 10000,
#    'pop': 0.35,
#    'rain': {'3h': 0.66},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 00:00:00'},
#   {'dt': 1680750000,
#    'main': {'temp': 278.31,
#     'feels_like': 276.99,
#     'temp_min': 278.31,
#     'temp_max': 278.31,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.74, 'deg': 52, 'gust': 3.85},
#    'visibility': 10000,
#    'pop': 0.64,
#    'rain': {'3h': 0.52},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 03:00:00'},
#   {'dt': 1680760800,
#    'main': {'temp': 278.7,
#     'feels_like': 278.7,
#     'temp_min': 278.7,
#     'temp_max': 278.7,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1022,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.43, 'deg': 5, 'gust': 0.63},
#    'visibility': 8099,
#    'pop': 0.61,
#    'rain': {'3h': 0.39},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 06:00:00'},
#   {'dt': 1680771600,
#    'main': {'temp': 279.93,
#     'feels_like': 278.97,
#     'temp_min': 279.93,
#     'temp_max': 279.93,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1020,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.63, 'deg': 176, 'gust': 8.64},
#    'visibility': 528,
#    'pop': 0.59,
#    'rain': {'3h': 0.93},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 09:00:00'},
#   {'dt': 1680782400,
#    'main': {'temp': 283.79,
#     'feels_like': 283.49,
#     'temp_min': 283.79,
#     'temp_max': 283.79,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1020,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.63, 'deg': 224, 'gust': 8.1},
#    'visibility': 153,
#    'pop': 0.68,
#    'rain': {'3h': 0.34},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 12:00:00'},
#   {'dt': 1680793200,
#    'main': {'temp': 287.79,
#     'feels_like': 287.79,
#     'temp_min': 287.79,
#     'temp_max': 287.79,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1019,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.98, 'deg': 227, 'gust': 11.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 15:00:00'},
#   {'dt': 1680804000,
#    'main': {'temp': 293.53,
#     'feels_like': 293.56,
#     'temp_min': 293.53,
#     'temp_max': 293.53,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1017,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.34, 'deg': 221, 'gust': 8.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 18:00:00'},
#   {'dt': 1680814800,
#    'main': {'temp': 294.13,
#     'feels_like': 294.14,
#     'temp_min': 294.13,
#     'temp_max': 294.13,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1016,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.25, 'deg': 235, 'gust': 8.93},
#    'visibility': 10000,
#    'pop': 0.18,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 21:00:00'},
#   {'dt': 1680825600,
#    'main': {'temp': 285.6,
#     'feels_like': 285.04,
#     'temp_min': 285.6,
#     'temp_max': 285.6,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1020,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.24, 'deg': 289, 'gust': 13.19},
#    'visibility': 7074,
#    'pop': 1,
#    'rain': {'3h': 3.6},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 00:00:00'},
#   {'dt': 1680836400,
#    'main': {'temp': 283.83,
#     'feels_like': 282.7,
#     'temp_min': 283.83,
#     'temp_max': 283.83,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1021,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.14, 'deg': 294, 'gust': 12.37},
#    'visibility': 10000,
#    'pop': 0.74,
#    'rain': {'3h': 2.66},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 03:00:00'},
#   {'dt': 1680847200,
#    'main': {'temp': 282.21,
#     'feels_like': 279.86,
#     'temp_min': 282.21,
#     'temp_max': 282.21,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1023,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.29, 'deg': 296, 'gust': 11.53},
#    'visibility': 10000,
#    'pop': 0.64,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 06:00:00'},
#   {'dt': 1680858000,
#    'main': {'temp': 280.53,
#     'feels_like': 278.09,
#     'temp_min': 280.53,
#     'temp_max': 280.53,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.7, 'deg': 284, 'gust': 11.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 09:00:00'},
#   {'dt': 1680868800,
#    'main': {'temp': 280.81,
#     'feels_like': 277.8,
#     'temp_min': 280.81,
#     'temp_max': 280.81,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 5.04, 'deg': 282, 'gust': 13.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 12:00:00'},
#   {'dt': 1680879600,
#    'main': {'temp': 283.48,
#     'feels_like': 281.51,
#     'temp_min': 283.48,
#     'temp_max': 283.48,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1025,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 6.86, 'deg': 286, 'gust': 12.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 15:00:00'},
#   {'dt': 1680890400,
#    'main': {'temp': 285.98,
#     'feels_like': 284,
#     'temp_min': 285.98,
#     'temp_max': 285.98,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 7.42, 'deg': 293, 'gust': 12.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 18:00:00'},
#   {'dt': 1680901200,
#    'main': {'temp': 284.8,
#     'feels_like': 282.73,
#     'temp_min': 284.8,
#     'temp_max': 284.8,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 6.36, 'deg': 299, 'gust': 11.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 21:00:00'},
#   {'dt': 1680912000,
#    'main': {'temp': 281.75,
#     'feels_like': 279.5,
#     'temp_min': 281.75,
#     'temp_max': 281.75,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1027,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 3.86, 'deg': 307, 'gust': 8.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 00:00:00'},
#   {'dt': 1680922800,
#    'main': {'temp': 279.32,
#     'feels_like': 276.92,
#     'temp_min': 279.32,
#     'temp_max': 279.32,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1029,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.21, 'deg': 341, 'gust': 6.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 03:00:00'},
#   {'dt': 1680933600,
#    'main': {'temp': 277.43,
#     'feels_like': 274.81,
#     'temp_min': 277.43,
#     'temp_max': 277.43,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1029,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.97, 'deg': 342, 'gust': 5.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 06:00:00'},
#   {'dt': 1680944400,
#    'main': {'temp': 276.37,
#     'feels_like': 274.94,
#     'temp_min': 276.37,
#     'temp_max': 276.37,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.59, 'deg': 332, 'gust': 2.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 09:00:00'},
#   {'dt': 1680955200,
#    'main': {'temp': 277.22,
#     'feels_like': 275.73,
#     'temp_min': 277.22,
#     'temp_max': 277.22,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1031,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.74, 'deg': 310, 'gust': 3.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 12:00:00'},
#   {'dt': 1680966000,
#    'main': {'temp': 280.26,
#     'feels_like': 277.98,
#     'temp_min': 280.26,
#     'temp_max': 280.26,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1031,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 3.33, 'deg': 315, 'gust': 6.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 15:00:00'},
#   {'dt': 1680976800,
#    'main': {'temp': 283.45,
#     'feels_like': 281.24,
#     'temp_min': 283.45,
#     'temp_max': 283.45,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1029,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 79},
#    'wind': {'speed': 3.11, 'deg': 336, 'gust': 6.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 18:00:00'},
#   {'dt': 1680987600,
#    'main': {'temp': 283.44,
#     'feels_like': 281.2,
#     'temp_min': 283.44,
#     'temp_max': 283.44,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1028,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 50},
#    'wind': {'speed': 2.01, 'deg': 359, 'gust': 4.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 21:00:00'},
#   {'dt': 1680998400,
#    'main': {'temp': 279.58,
#     'feels_like': 278.14,
#     'temp_min': 279.58,
#     'temp_max': 279.58,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 2.05, 'deg': 129, 'gust': 3.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-09 00:00:00'}],
#  'city': {'id': 4930956,
#   'name': 'Boston',
#   'coord': {'lat': 42.3584, 'lon': -71.0598},
#   'country': 'US',
#   'population': 617594,
#   'timezone': -14400,
#   'sunrise': 1680517414,
#   'sunset': 1680563473}}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1680577200,
#    'main': {'temp': 281.9,
#     'feels_like': 279.4,
#     'temp_min': 280.86,
#     'temp_max': 281.9,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1017,
#     'humidity': 65,
#     'temp_kf': 1.04},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.47, 'deg': 227, 'gust': 14.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-04 03:00:00'},
#   {'dt': 1680588000,
#    'main': {'temp': 281.6,
#     'feels_like': 279.64,
#     'temp_min': 280.99,
#     'temp_max': 281.6,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1017,
#     'humidity': 69,
#     'temp_kf': 0.61},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.26, 'deg': 224, 'gust': 8.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-04 06:00:00'},
#   {'dt': 1680598800,
#    'main': {'temp': 280.97,
#     'feels_like': 280.97,
#     'temp_min': 280.5,
#     'temp_max': 280.97,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1017,
#     'humidity': 77,
#     'temp_kf': 0.47},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.33, 'deg': 226, 'gust': 2.13},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-04 09:00:00'},
#   {'dt': 1680609600,
#    'main': {'temp': 281.35,
#     'feels_like': 280.82,
#     'temp_min': 281.35,
#     'temp_max': 281.35,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.44, 'deg': 297, 'gust': 3.2},
#    'visibility': 10000,
#    'pop': 0.49,
#    'rain': {'3h': 0.33},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 12:00:00'},
#   {'dt': 1680620400,
#    'main': {'temp': 283.72,
#     'feels_like': 282.56,
#     'temp_min': 283.72,
#     'temp_max': 283.72,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1019,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.01, 'deg': 21, 'gust': 0.71},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 15:00:00'},
#   {'dt': 1680631200,
#    'main': {'temp': 287.36,
#     'feels_like': 286.32,
#     'temp_min': 287.36,
#     'temp_max': 287.36,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 2.15, 'deg': 69, 'gust': 2.62},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 18:00:00'},
#   {'dt': 1680642000,
#    'main': {'temp': 283.58,
#     'feels_like': 282.53,
#     'temp_min': 283.58,
#     'temp_max': 283.58,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1020,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.56, 'deg': 76, 'gust': 5.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 21:00:00'},
#   {'dt': 1680652800,
#    'main': {'temp': 281.56,
#     'feels_like': 279.57,
#     'temp_min': 281.56,
#     'temp_max': 281.56,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1023,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.31, 'deg': 61, 'gust': 6.05},
#    'visibility': 10000,
#    'pop': 0.22,
#    'rain': {'3h': 0.2},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 00:00:00'},
#   {'dt': 1680663600,
#    'main': {'temp': 280.72,
#     'feels_like': 278.94,
#     'temp_min': 280.72,
#     'temp_max': 280.72,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.71, 'deg': 50, 'gust': 4.82},
#    'visibility': 10000,
#    'pop': 0.25,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 03:00:00'},
#   {'dt': 1680674400,
#    'main': {'temp': 280.17,
#     'feels_like': 277.81,
#     'temp_min': 280.17,
#     'temp_max': 280.17,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1026,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.43, 'deg': 48, 'gust': 6.96},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 06:00:00'},
#   {'dt': 1680685200,
#    'main': {'temp': 278.47,
#     'feels_like': 274.88,
#     'temp_min': 278.47,
#     'temp_max': 278.47,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1028,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.01, 'deg': 64, 'gust': 9.13},
#    'visibility': 10000,
#    'pop': 0.56,
#    'rain': {'3h': 0.26},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 09:00:00'},
#   {'dt': 1680696000,
#    'main': {'temp': 277.75,
#     'feels_like': 273.68,
#     'temp_min': 277.75,
#     'temp_max': 277.75,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.66, 'deg': 63, 'gust': 10.07},
#    'visibility': 10000,
#    'pop': 0.23,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 12:00:00'},
#   {'dt': 1680706800,
#    'main': {'temp': 278.03,
#     'feels_like': 274.27,
#     'temp_min': 278.03,
#     'temp_max': 278.03,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.14, 'deg': 77, 'gust': 8.44},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 15:00:00'},
#   {'dt': 1680717600,
#    'main': {'temp': 277.68,
#     'feels_like': 273.79,
#     'temp_min': 277.68,
#     'temp_max': 277.68,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1029,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.23, 'deg': 89, 'gust': 8.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 18:00:00'},
#   {'dt': 1680728400,
#    'main': {'temp': 277.71,
#     'feels_like': 274.45,
#     'temp_min': 277.71,
#     'temp_max': 277.71,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1028,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.04, 'deg': 93, 'gust': 7.36},
#    'visibility': 10000,
#    'pop': 0.23,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 21:00:00'},
#   {'dt': 1680739200,
#    'main': {'temp': 277.85,
#     'feels_like': 275.42,
#     'temp_min': 277.85,
#     'temp_max': 277.85,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1027,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.84, 'deg': 67, 'gust': 6.08},
#    'visibility': 10000,
#    'pop': 0.35,
#    'rain': {'3h': 0.66},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 00:00:00'},
#   {'dt': 1680750000,
#    'main': {'temp': 278.31,
#     'feels_like': 276.99,
#     'temp_min': 278.31,
#     'temp_max': 278.31,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.74, 'deg': 52, 'gust': 3.85},
#    'visibility': 10000,
#    'pop': 0.64,
#    'rain': {'3h': 0.52},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 03:00:00'},
#   {'dt': 1680760800,
#    'main': {'temp': 278.7,
#     'feels_like': 278.7,
#     'temp_min': 278.7,
#     'temp_max': 278.7,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1022,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.43, 'deg': 5, 'gust': 0.63},
#    'visibility': 8099,
#    'pop': 0.61,
#    'rain': {'3h': 0.39},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 06:00:00'},
#   {'dt': 1680771600,
#    'main': {'temp': 279.93,
#     'feels_like': 278.97,
#     'temp_min': 279.93,
#     'temp_max': 279.93,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1020,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.63, 'deg': 176, 'gust': 8.64},
#    'visibility': 528,
#    'pop': 0.59,
#    'rain': {'3h': 0.93},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 09:00:00'},
#   {'dt': 1680782400,
#    'main': {'temp': 283.79,
#     'feels_like': 283.49,
#     'temp_min': 283.79,
#     'temp_max': 283.79,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1020,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.63, 'deg': 224, 'gust': 8.1},
#    'visibility': 153,
#    'pop': 0.68,
#    'rain': {'3h': 0.34},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 12:00:00'},
#   {'dt': 1680793200,
#    'main': {'temp': 287.79,
#     'feels_like': 287.79,
#     'temp_min': 287.79,
#     'temp_max': 287.79,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1019,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.98, 'deg': 227, 'gust': 11.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 15:00:00'},
#   {'dt': 1680804000,
#    'main': {'temp': 293.53,
#     'feels_like': 293.56,
#     'temp_min': 293.53,
#     'temp_max': 293.53,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1017,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.34, 'deg': 221, 'gust': 8.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 18:00:00'},
#   {'dt': 1680814800,
#    'main': {'temp': 294.13,
#     'feels_like': 294.14,
#     'temp_min': 294.13,
#     'temp_max': 294.13,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1016,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.25, 'deg': 235, 'gust': 8.93},
#    'visibility': 10000,
#    'pop': 0.18,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 21:00:00'},
#   {'dt': 1680825600,
#    'main': {'temp': 285.6,
#     'feels_like': 285.04,
#     'temp_min': 285.6,
#     'temp_max': 285.6,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1020,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.24, 'deg': 289, 'gust': 13.19},
#    'visibility': 7074,
#    'pop': 1,
#    'rain': {'3h': 3.6},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 00:00:00'},
#   {'dt': 1680836400,
#    'main': {'temp': 283.83,
#     'feels_like': 282.7,
#     'temp_min': 283.83,
#     'temp_max': 283.83,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1021,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.14, 'deg': 294, 'gust': 12.37},
#    'visibility': 10000,
#    'pop': 0.74,
#    'rain': {'3h': 2.66},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 03:00:00'},
#   {'dt': 1680847200,
#    'main': {'temp': 282.21,
#     'feels_like': 279.86,
#     'temp_min': 282.21,
#     'temp_max': 282.21,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1023,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.29, 'deg': 296, 'gust': 11.53},
#    'visibility': 10000,
#    'pop': 0.64,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 06:00:00'},
#   {'dt': 1680858000,
#    'main': {'temp': 280.53,
#     'feels_like': 278.09,
#     'temp_min': 280.53,
#     'temp_max': 280.53,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.7, 'deg': 284, 'gust': 11.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 09:00:00'},
#   {'dt': 1680868800,
#    'main': {'temp': 280.81,
#     'feels_like': 277.8,
#     'temp_min': 280.81,
#     'temp_max': 280.81,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 5.04, 'deg': 282, 'gust': 13.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 12:00:00'},
#   {'dt': 1680879600,
#    'main': {'temp': 283.48,
#     'feels_like': 281.51,
#     'temp_min': 283.48,
#     'temp_max': 283.48,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1025,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 6.86, 'deg': 286, 'gust': 12.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 15:00:00'},
#   {'dt': 1680890400,
#    'main': {'temp': 285.98,
#     'feels_like': 284,
#     'temp_min': 285.98,
#     'temp_max': 285.98,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 7.42, 'deg': 293, 'gust': 12.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 18:00:00'},
#   {'dt': 1680901200,
#    'main': {'temp': 284.8,
#     'feels_like': 282.73,
#     'temp_min': 284.8,
#     'temp_max': 284.8,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 6.36, 'deg': 299, 'gust': 11.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 21:00:00'},
#   {'dt': 1680912000,
#    'main': {'temp': 281.75,
#     'feels_like': 279.5,
#     'temp_min': 281.75,
#     'temp_max': 281.75,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1027,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 3.86, 'deg': 307, 'gust': 8.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 00:00:00'},
#   {'dt': 1680922800,
#    'main': {'temp': 279.32,
#     'feels_like': 276.92,
#     'temp_min': 279.32,
#     'temp_max': 279.32,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1029,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.21, 'deg': 341, 'gust': 6.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 03:00:00'},
#   {'dt': 1680933600,
#    'main': {'temp': 277.43,
#     'feels_like': 274.81,
#     'temp_min': 277.43,
#     'temp_max': 277.43,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1029,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.97, 'deg': 342, 'gust': 5.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 06:00:00'},
#   {'dt': 1680944400,
#    'main': {'temp': 276.37,
#     'feels_like': 274.94,
#     'temp_min': 276.37,
#     'temp_max': 276.37,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.59, 'deg': 332, 'gust': 2.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 09:00:00'},
#   {'dt': 1680955200,
#    'main': {'temp': 277.22,
#     'feels_like': 275.73,
#     'temp_min': 277.22,
#     'temp_max': 277.22,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1031,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.74, 'deg': 310, 'gust': 3.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 12:00:00'},
#   {'dt': 1680966000,
#    'main': {'temp': 280.26,
#     'feels_like': 277.98,
#     'temp_min': 280.26,
#     'temp_max': 280.26,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1031,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 3.33, 'deg': 315, 'gust': 6.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 15:00:00'},
#   {'dt': 1680976800,
#    'main': {'temp': 283.45,
#     'feels_like': 281.24,
#     'temp_min': 283.45,
#     'temp_max': 283.45,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1029,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 79},
#    'wind': {'speed': 3.11, 'deg': 336, 'gust': 6.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 18:00:00'},
#   {'dt': 1680987600,
#    'main': {'temp': 283.44,
#     'feels_like': 281.2,
#     'temp_min': 283.44,
#     'temp_max': 283.44,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1028,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 50},
#    'wind': {'speed': 2.01, 'deg': 359, 'gust': 4.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 21:00:00'},
#   {'dt': 1680998400,
#    'main': {'temp': 279.58,
#     'feels_like': 278.14,
#     'temp_min': 279.58,
#     'temp_max': 279.58,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 2.05, 'deg': 129, 'gust': 3.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-09 00:00:00'}],
#  'city': {'id': 4930956,
#   'name': 'Boston',
#   'coord': {'lat': 42.3584, 'lon': -71.0598},
#   'country': 'US',
#   'population': 617594,
#   'timezone': -14400,
#   'sunrise': 1680517414,
#   'sunset': 1680563473}}

# %%
#Retrieve the corresponding value
boston_data['list'][6]['sys']
# Out:
# {'pod': 'd'}

# %%
# Get the JSON data.
boston_data = city_weather.json()
boston_data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1680577200,
#    'main': {'temp': 281.9,
#     'feels_like': 279.4,
#     'temp_min': 280.86,
#     'temp_max': 281.9,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1017,
#     'humidity': 65,
#     'temp_kf': 1.04},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.47, 'deg': 227, 'gust': 14.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-04 03:00:00'},
#   {'dt': 1680588000,
#    'main': {'temp': 281.6,
#     'feels_like': 279.64,
#     'temp_min': 280.99,
#     'temp_max': 281.6,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1017,
#     'humidity': 69,
#     'temp_kf': 0.61},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.26, 'deg': 224, 'gust': 8.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-04 06:00:00'},
#   {'dt': 1680598800,
#    'main': {'temp': 280.97,
#     'feels_like': 280.97,
#     'temp_min': 280.5,
#     'temp_max': 280.97,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1017,
#     'humidity': 77,
#     'temp_kf': 0.47},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.33, 'deg': 226, 'gust': 2.13},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-04 09:00:00'},
#   {'dt': 1680609600,
#    'main': {'temp': 281.35,
#     'feels_like': 280.82,
#     'temp_min': 281.35,
#     'temp_max': 281.35,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.44, 'deg': 297, 'gust': 3.2},
#    'visibility': 10000,
#    'pop': 0.49,
#    'rain': {'3h': 0.33},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 12:00:00'},
#   {'dt': 1680620400,
#    'main': {'temp': 283.72,
#     'feels_like': 282.56,
#     'temp_min': 283.72,
#     'temp_max': 283.72,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1019,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.01, 'deg': 21, 'gust': 0.71},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 15:00:00'},
#   {'dt': 1680631200,
#    'main': {'temp': 287.36,
#     'feels_like': 286.32,
#     'temp_min': 287.36,
#     'temp_max': 287.36,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1018,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 2.15, 'deg': 69, 'gust': 2.62},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 18:00:00'},
#   {'dt': 1680642000,
#    'main': {'temp': 283.58,
#     'feels_like': 282.53,
#     'temp_min': 283.58,
#     'temp_max': 283.58,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1020,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.56, 'deg': 76, 'gust': 5.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-04 21:00:00'},
#   {'dt': 1680652800,
#    'main': {'temp': 281.56,
#     'feels_like': 279.57,
#     'temp_min': 281.56,
#     'temp_max': 281.56,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1023,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.31, 'deg': 61, 'gust': 6.05},
#    'visibility': 10000,
#    'pop': 0.22,
#    'rain': {'3h': 0.2},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 00:00:00'},
#   {'dt': 1680663600,
#    'main': {'temp': 280.72,
#     'feels_like': 278.94,
#     'temp_min': 280.72,
#     'temp_max': 280.72,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.71, 'deg': 50, 'gust': 4.82},
#    'visibility': 10000,
#    'pop': 0.25,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 03:00:00'},
#   {'dt': 1680674400,
#    'main': {'temp': 280.17,
#     'feels_like': 277.81,
#     'temp_min': 280.17,
#     'temp_max': 280.17,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1026,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.43, 'deg': 48, 'gust': 6.96},
#    'visibility': 10000,
#    'pop': 0.29,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 06:00:00'},
#   {'dt': 1680685200,
#    'main': {'temp': 278.47,
#     'feels_like': 274.88,
#     'temp_min': 278.47,
#     'temp_max': 278.47,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1028,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.01, 'deg': 64, 'gust': 9.13},
#    'visibility': 10000,
#    'pop': 0.56,
#    'rain': {'3h': 0.26},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-05 09:00:00'},
#   {'dt': 1680696000,
#    'main': {'temp': 277.75,
#     'feels_like': 273.68,
#     'temp_min': 277.75,
#     'temp_max': 277.75,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.66, 'deg': 63, 'gust': 10.07},
#    'visibility': 10000,
#    'pop': 0.23,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 12:00:00'},
#   {'dt': 1680706800,
#    'main': {'temp': 278.03,
#     'feels_like': 274.27,
#     'temp_min': 278.03,
#     'temp_max': 278.03,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.14, 'deg': 77, 'gust': 8.44},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 15:00:00'},
#   {'dt': 1680717600,
#    'main': {'temp': 277.68,
#     'feels_like': 273.79,
#     'temp_min': 277.68,
#     'temp_max': 277.68,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1029,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.23, 'deg': 89, 'gust': 8.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 18:00:00'},
#   {'dt': 1680728400,
#    'main': {'temp': 277.71,
#     'feels_like': 274.45,
#     'temp_min': 277.71,
#     'temp_max': 277.71,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1028,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.04, 'deg': 93, 'gust': 7.36},
#    'visibility': 10000,
#    'pop': 0.23,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-05 21:00:00'},
#   {'dt': 1680739200,
#    'main': {'temp': 277.85,
#     'feels_like': 275.42,
#     'temp_min': 277.85,
#     'temp_max': 277.85,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1027,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.84, 'deg': 67, 'gust': 6.08},
#    'visibility': 10000,
#    'pop': 0.35,
#    'rain': {'3h': 0.66},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 00:00:00'},
#   {'dt': 1680750000,
#    'main': {'temp': 278.31,
#     'feels_like': 276.99,
#     'temp_min': 278.31,
#     'temp_max': 278.31,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.74, 'deg': 52, 'gust': 3.85},
#    'visibility': 10000,
#    'pop': 0.64,
#    'rain': {'3h': 0.52},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 03:00:00'},
#   {'dt': 1680760800,
#    'main': {'temp': 278.7,
#     'feels_like': 278.7,
#     'temp_min': 278.7,
#     'temp_max': 278.7,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1022,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.43, 'deg': 5, 'gust': 0.63},
#    'visibility': 8099,
#    'pop': 0.61,
#    'rain': {'3h': 0.39},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 06:00:00'},
#   {'dt': 1680771600,
#    'main': {'temp': 279.93,
#     'feels_like': 278.97,
#     'temp_min': 279.93,
#     'temp_max': 279.93,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1020,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.63, 'deg': 176, 'gust': 8.64},
#    'visibility': 528,
#    'pop': 0.59,
#    'rain': {'3h': 0.93},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-06 09:00:00'},
#   {'dt': 1680782400,
#    'main': {'temp': 283.79,
#     'feels_like': 283.49,
#     'temp_min': 283.79,
#     'temp_max': 283.79,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1020,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.63, 'deg': 224, 'gust': 8.1},
#    'visibility': 153,
#    'pop': 0.68,
#    'rain': {'3h': 0.34},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 12:00:00'},
#   {'dt': 1680793200,
#    'main': {'temp': 287.79,
#     'feels_like': 287.79,
#     'temp_min': 287.79,
#     'temp_max': 287.79,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1019,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.98, 'deg': 227, 'gust': 11.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 15:00:00'},
#   {'dt': 1680804000,
#    'main': {'temp': 293.53,
#     'feels_like': 293.56,
#     'temp_min': 293.53,
#     'temp_max': 293.53,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1017,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.34, 'deg': 221, 'gust': 8.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 18:00:00'},
#   {'dt': 1680814800,
#    'main': {'temp': 294.13,
#     'feels_like': 294.14,
#     'temp_min': 294.13,
#     'temp_max': 294.13,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1016,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.25, 'deg': 235, 'gust': 8.93},
#    'visibility': 10000,
#    'pop': 0.18,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-06 21:00:00'},
#   {'dt': 1680825600,
#    'main': {'temp': 285.6,
#     'feels_like': 285.04,
#     'temp_min': 285.6,
#     'temp_max': 285.6,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1020,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.24, 'deg': 289, 'gust': 13.19},
#    'visibility': 7074,
#    'pop': 1,
#    'rain': {'3h': 3.6},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 00:00:00'},
#   {'dt': 1680836400,
#    'main': {'temp': 283.83,
#     'feels_like': 282.7,
#     'temp_min': 283.83,
#     'temp_max': 283.83,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1021,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.14, 'deg': 294, 'gust': 12.37},
#    'visibility': 10000,
#    'pop': 0.74,
#    'rain': {'3h': 2.66},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 03:00:00'},
#   {'dt': 1680847200,
#    'main': {'temp': 282.21,
#     'feels_like': 279.86,
#     'temp_min': 282.21,
#     'temp_max': 282.21,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1023,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.29, 'deg': 296, 'gust': 11.53},
#    'visibility': 10000,
#    'pop': 0.64,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 06:00:00'},
#   {'dt': 1680858000,
#    'main': {'temp': 280.53,
#     'feels_like': 278.09,
#     'temp_min': 280.53,
#     'temp_max': 280.53,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.7, 'deg': 284, 'gust': 11.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-07 09:00:00'},
#   {'dt': 1680868800,
#    'main': {'temp': 280.81,
#     'feels_like': 277.8,
#     'temp_min': 280.81,
#     'temp_max': 280.81,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 5.04, 'deg': 282, 'gust': 13.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 12:00:00'},
#   {'dt': 1680879600,
#    'main': {'temp': 283.48,
#     'feels_like': 281.51,
#     'temp_min': 283.48,
#     'temp_max': 283.48,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1025,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 6.86, 'deg': 286, 'gust': 12.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 15:00:00'},
#   {'dt': 1680890400,
#    'main': {'temp': 285.98,
#     'feels_like': 284,
#     'temp_min': 285.98,
#     'temp_max': 285.98,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1024,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 7.42, 'deg': 293, 'gust': 12.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 18:00:00'},
#   {'dt': 1680901200,
#    'main': {'temp': 284.8,
#     'feels_like': 282.73,
#     'temp_min': 284.8,
#     'temp_max': 284.8,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1025,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 6.36, 'deg': 299, 'gust': 11.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-07 21:00:00'},
#   {'dt': 1680912000,
#    'main': {'temp': 281.75,
#     'feels_like': 279.5,
#     'temp_min': 281.75,
#     'temp_max': 281.75,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1027,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 3.86, 'deg': 307, 'gust': 8.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 00:00:00'},
#   {'dt': 1680922800,
#    'main': {'temp': 279.32,
#     'feels_like': 276.92,
#     'temp_min': 279.32,
#     'temp_max': 279.32,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1029,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.21, 'deg': 341, 'gust': 6.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 03:00:00'},
#   {'dt': 1680933600,
#    'main': {'temp': 277.43,
#     'feels_like': 274.81,
#     'temp_min': 277.43,
#     'temp_max': 277.43,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1029,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.97, 'deg': 342, 'gust': 5.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 06:00:00'},
#   {'dt': 1680944400,
#    'main': {'temp': 276.37,
#     'feels_like': 274.94,
#     'temp_min': 276.37,
#     'temp_max': 276.37,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.59, 'deg': 332, 'gust': 2.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-08 09:00:00'},
#   {'dt': 1680955200,
#    'main': {'temp': 277.22,
#     'feels_like': 275.73,
#     'temp_min': 277.22,
#     'temp_max': 277.22,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1031,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.74, 'deg': 310, 'gust': 3.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 12:00:00'},
#   {'dt': 1680966000,
#    'main': {'temp': 280.26,
#     'feels_like': 277.98,
#     'temp_min': 280.26,
#     'temp_max': 280.26,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1031,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 3.33, 'deg': 315, 'gust': 6.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 15:00:00'},
#   {'dt': 1680976800,
#    'main': {'temp': 283.45,
#     'feels_like': 281.24,
#     'temp_min': 283.45,
#     'temp_max': 283.45,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1029,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 79},
#    'wind': {'speed': 3.11, 'deg': 336, 'gust': 6.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 18:00:00'},
#   {'dt': 1680987600,
#    'main': {'temp': 283.44,
#     'feels_like': 281.2,
#     'temp_min': 283.44,
#     'temp_max': 283.44,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1028,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 50},
#    'wind': {'speed': 2.01, 'deg': 359, 'gust': 4.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-04-08 21:00:00'},
#   {'dt': 1680998400,
#    'main': {'temp': 279.58,
#     'feels_like': 278.14,
#     'temp_min': 279.58,
#     'temp_max': 279.58,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1030,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 2.05, 'deg': 129, 'gust': 3.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-04-09 00:00:00'}],
#  'city': {'id': 4930956,
#   'name': 'Boston',
#   'coord': {'lat': 42.3584, 'lon': -71.0598},
#   'country': 'US',
#   'population': 617594,
#   'timezone': -14400,
#   'sunrise': 1680517414,
#   'sunset': 1680563473}}

# %%
#Find country for Boston
boston_data['city']['country']
# Out:
# 'US'

# %%
# #Retrieve the date in the weather data
# boston_data.get("dt")
# boston_data

# %%
lat = boston_data['city']["coord"]["lat"]
lng = boston_data['city']["coord"]["lon"]
max_temp = boston_data['list'][0]['main']["temp_max"]
humidity = boston_data['list'][0]['main']["humidity"]
clouds = boston_data['list'][2]["clouds"]["all"]
wind = boston_data['list'][3]["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 281.9 65 99 1.44

# %%
# Import the time library and datetime module from the datetime library.
import time
from datetime import datetime

# Get the date from the JSON file.
date = boston_data['list'][0]['dt']

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2023-04-04 03:00:00'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1


    city_weather = requests.get(city_url).json()
    print(city_weather)
    max_temp = city_weather["list"][0]["main"]['temp_max']
    latitude = city_weather['city']['coord']['lat']
    longitude = city_weather['city']['coord']['lon']
    humidity = city_weather["list"][0]["main"]['humidity']
    cloudiness = city_weather['clouds']['all']
    wind = city_weather['wind']['speed']
    country = city_weather['country']
    weather_description = city_weather['weather']['description']

#     # Run an API request for each of the cities
#     try:
#         #city_weather = requests.get(city_url).json()
#         # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
#         # print(city_weather)   
#         # # 
#         # max_temp = city_weather["list"][0]["main"]['temp_max']
#         # latitude = city_weather['city']['coord']['lat']
#         # longitude = city_weather['city']['coord']['lon']
#         # humidity = city_weather["list"][0]["main"]['humidity']
#         #cloudiness = city_weather['clouds']['all']
#         # wind = city_weather['wind']['speed']
#         # country = city_weather['country']
#         # weather_description = city_weather['weather']['description']

        


#         # Append the city information into the city_data list
#         # YOUR CODE HERE
#         if city not in cities:
#             cities.append(city)
    
#     # If an error is experienced, skip the city
#     except:
#         print("City not found. Skipping...")
#         pass

# # Indicate that the data retrieval is complete 
# print("-----------------------------")
# print("Data Retrieval Complete      ")
# print("-----------------------------")

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = # YOUR CODE HERE

# %%
# Display sample data
city_data_df.head(10)

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
