# %%
# Create a practice set of random latitude and longitude combinations.
lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
lat_lngs = zip(lats, lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# nanortalik gl
# omsukchan ru
# dunedin nz
# barrow us
# luderitz na
# atka ru
# atuona pf
# hobart au
# praxedis guerrero mx
# vaini to
# ushuaia ar
# port alfred za
# san patricio mx
# antofagasta cl
# punta arenas cl
# rikitea pf
# ushuaia ar
# saint-augustin ca
# sorkjosen no
# dikson ru
# lima pe
# progreso mx
# mar del plata ar
# osterhofen de
# illoqqortoormiut gl
# taolanaro mg
# castro cl
# sobolevo ru
# harrai in
# saint-philippe re
# cape town za
# marcona pe
# san patricio mx
# punta arenas cl
# hilo us
# keti bandar pk
# tura ru
# alofi nu
# narasaraopet in
# arraial do cabo br
# san francisco ar
# dubrovnik hr
# hobart au
# urdzhar kz
# souillac mu
# anadyr ru
# farmington us
# ushuaia ar
# rikitea pf
# whitehorse ca
# duldurga ru
# ghotki pk
# sur om
# ixtapa mx
# tuatapere nz
# lavrentiya ru
# vaini to
# rikitea pf
# vaitupu wf
# guerrero negro mx
# palabuhanratu id
# atar mr
# qaanaaq gl
# touros br
# punta arenas cl
# chuy uy
# grand gaube mu
# yellowknife ca
# ...

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a37a5508179f05bd6b3be8813c556848

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a37a5508179f05bd6b3be8813c556848&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Direct call of response code
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}],"base":"stations","main":{"temp":38.97,"feels_like":31.73,"temp_min":35.15,"temp_max":42.6,"pressure":1022,"humidity":25},"visibility":10000,"wind":{"speed":11.5,"deg":320,"gust":26.46},"clouds":{"all":20},"dt":1680198819,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1680172230,"sunset":1680217605},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 38.97,
#   'feels_like': 31.73,
#   'temp_min': 35.15,
#   'temp_max': 42.6,
#   'pressure': 1022,
#   'humidity': 25},
#  'visibility': 10000,
#  'wind': {'speed': 11.5, 'deg': 320, 'gust': 26.46},
#  'clouds': {'all': 20},
#  'dt': 1680198819,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1680172230,
#   'sunset': 1680217605},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city (JSON formatted data)
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city. ***corrected spelling of 'Boston'***
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 38.97,
#   'feels_like': 31.73,
#   'temp_min': 35.15,
#   'temp_max': 42.6,
#   'pressure': 1022,
#   'humidity': 25},
#  'visibility': 10000,
#  'wind': {'speed': 11.5, 'deg': 320, 'gust': 26.46},
#  'clouds': {'all': 20},
#  'dt': 1680198819,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1680172230,
#   'sunset': 1680217605},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
# Retrieve the corresponding value
boston_data['sys']
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1680172230,
#  'sunset': 1680217605}

# %%
# Retrieve the corresponding value
boston_data['sys']['country']
# Out:
# 'US'

# %%
# Retrieve the date in the weather data
boston_data['dt']
# Out:
# 1680198819

# %%
# Using similar context as finding time of day, find latitude, longitude, max temp, humidity, percent cloudiness, and wind speed. 
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 42.6 25 20 11.5

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Get the date from the JSON file.
date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2023, 3, 30, 17, 53, 39)

# %%
# Import the datetime module from the datetime library. Add .strftime('%Y-%m-%d %H:%M:%S') to format. 
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2023-03-30 17:53:39'
